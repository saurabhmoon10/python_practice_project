# %% [markdown]
# # Data cleaning

# %%
#loading the necessary libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# loading the data 
data=pd.read_csv(r"D:\datasets\ryanair_airplane_review.csv")

# %%
data
# Out:
#       Unnamed: 0 Date Published  Overall Rating Passenger Country  \
# 0              0     2024-02-03            10.0    United Kingdom
# 1              1     2024-01-26            10.0    United Kingdom
# 2              2     2024-01-20            10.0    United Kingdom
# 3              3     2024-01-07             6.0    United Kingdom
# 4              4     2024-01-06            10.0            Israel
# ...          ...            ...             ...               ...
# 2244        2244     2012-08-28             2.0    United Kingdom
# 2245        2245     2012-08-28             1.0    United Kingdom
# 2246        2246     2012-08-28             1.0    United Kingdom
# 2247        2247     2012-08-28             1.0         Australia
# 2248        2248     2012-08-23             2.0    United Kingdom
#
#       Trip_verified                             Comment title  \
# 0      Not Verified         "bang on time and smooth flights"
# ...

# %%
# copying the data in new variable.
df=data.copy()

# %%
df.head()
# Out:
#    Unnamed: 0 Date Published  Overall Rating Passenger Country  Trip_verified  \
# 0           0     2024-02-03            10.0    United Kingdom   Not Verified
# 1           1     2024-01-26            10.0    United Kingdom  Trip Verified
# 2           2     2024-01-20            10.0    United Kingdom  Trip Verified
# 3           3     2024-01-07             6.0    United Kingdom  Trip Verified
# 4           4     2024-01-06            10.0            Israel  Trip Verified
#
#                               Comment title  \
# 0         "bang on time and smooth flights"
# 1          "Another good affordable flight"
# 2                       “Really impressed!”
# 3          “a decent offering from Ryanair”
# 4  “cabin crew were welcoming and friendly”
#
#                                              Comment        Aircraft  \
# 0  Flew back from Faro to London Luton Friday 2nd...  Boeing 737 900
# 1  Another good affordable flight with Ryanair. O...             NaN
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0 Date Published  Overall Rating Passenger Country  \
# 2244        2244     2012-08-28             2.0    United Kingdom
# 2245        2245     2012-08-28             1.0    United Kingdom
# 2246        2246     2012-08-28             1.0    United Kingdom
# 2247        2247     2012-08-28             1.0         Australia
# 2248        2248     2012-08-23             2.0    United Kingdom
#
#      Trip_verified            Comment title  \
# 2244           NaN  Ryanair customer review
# 2245           NaN  Ryanair customer review
# 2246           NaN  Ryanair customer review
# 2247           NaN  Ryanair customer review
# 2248           NaN  Ryanair customer review
#
#                                                 Comment Aircraft  \
# 2244  Myself and my daughter took a holiday to Kos. ...      NaN
# 2245  Stansted to Pula. Tried to adhere to all rules...      NaN
# 2246  When printing the boarding tickets we got our ...      NaN
# ...

# %%
# checking the information about the data.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2249 entries, 0 to 2248
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              2249 non-null   int64
#  1   Date Published          2249 non-null   object
#  2   Overall Rating          2119 non-null   float64
#  3   Passenger Country       2249 non-null   object
#  4   Trip_verified           1305 non-null   object
#  5   Comment title           2249 non-null   object
#  6   Comment                 2249 non-null   object
#  7   Aircraft                551 non-null    object
#  8   Type Of Traveller       1635 non-null   object
#  9   Seat Type               2249 non-null   object
#  10  Origin                  1634 non-null   object
#  11  Destination             1634 non-null   object
#  12  Date Flown              1631 non-null   object
#  13  Seat Comfort            2137 non-null   float64
# ...

# %%
# describing the data
df.describe()
# Out:
#         Unnamed: 0  Overall Rating  Seat Comfort  Cabin Staff Service  \
# count  2249.000000     2119.000000   2137.000000          2128.000000
# mean   1124.000000        4.380368      2.373421             2.747180
# std     649.374699        3.554740      1.290634             1.535351
# min       0.000000        1.000000      0.000000             0.000000
# 25%     562.000000        1.000000      1.000000             1.000000
# 50%    1124.000000        3.000000      2.000000             3.000000
# 75%    1686.000000        8.000000      3.000000             4.000000
# max    2248.000000       10.000000      5.000000             5.000000
#
#        Food & Beverages  Ground Service  Value For Money  \
# count       1312.000000     1578.000000      2248.000000
# mean           1.921494        2.156527         2.731762
# std            1.492650        1.491115         1.692578
# min            0.000000        1.000000         0.000000
# ...

# %%
# dropping the unecessary column from the data
df.drop(columns="Unnamed: 0",axis=1,inplace=True)

# %%
df
# Out:
#      Date Published  Overall Rating Passenger Country  Trip_verified  \
# 0        2024-02-03            10.0    United Kingdom   Not Verified
# 1        2024-01-26            10.0    United Kingdom  Trip Verified
# 2        2024-01-20            10.0    United Kingdom  Trip Verified
# 3        2024-01-07             6.0    United Kingdom  Trip Verified
# 4        2024-01-06            10.0            Israel  Trip Verified
# ...             ...             ...               ...            ...
# 2244     2012-08-28             2.0    United Kingdom            NaN
# 2245     2012-08-28             1.0    United Kingdom            NaN
# 2246     2012-08-28             1.0    United Kingdom            NaN
# 2247     2012-08-28             1.0         Australia            NaN
# 2248     2012-08-23             2.0    United Kingdom            NaN
#
#                                  Comment title  \
# 0            "bang on time and smooth flights"
# ...

# %%
# checking for the null values.
df.isnull().sum().sort_values(ascending=False)
# Out:
# Wifi & Connectivity       1981
# Inflight Entertainment    1918
# Aircraft                  1698
# Trip_verified              944
# Food & Beverages           937
# Ground Service             671
# Date Flown                 618
# Origin                     615
# Destination                615
# Type Of Traveller          614
# Overall Rating             130
# Cabin Staff Service        121
# Seat Comfort               112
# Value For Money              1
# Seat Type                    0
# Comment                      0
# Comment title                0
# Recommended                  0
# Passenger Country            0
# Date Published               0
# dtype: int64

# %% [markdown]
# Rrport:-
#
#     There are maximum null values present in wifi and connectivity column.

# %%
# checking for the percentage of null values present in our data.
(df.isnull().sum()/len(df))*100
# Out:
# Date Published             0.000000
# Overall Rating             5.780347
# Passenger Country          0.000000
# Trip_verified             41.974211
# Comment title              0.000000
# Comment                    0.000000
# Aircraft                  75.500222
# Type Of Traveller         27.301023
# Seat Type                  0.000000
# Origin                    27.345487
# Destination               27.345487
# Date Flown                27.478880
# Seat Comfort               4.979991
# Cabin Staff Service        5.380169
# Food & Beverages          41.662961
# Ground Service            29.835482
# Value For Money            0.044464
# Recommended                0.000000
# Inflight Entertainment    85.282348
# Wifi & Connectivity       88.083593
# dtype: float64

# %%
#Checking the skewness of all the columns before fillling the null values.
print(sb.kdeplot(df["Overall Rating"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sb.kdeplot(df["Seat Comfort"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sb.kdeplot(df["Cabin Staff Service"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sb.kdeplot(df['Food & Beverages']))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sb.kdeplot(df["Ground Service"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sb.kdeplot(df["Value For Money"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sb.kdeplot(df["Inflight Entertainment"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sb.kdeplot(df["Wifi & Connectivity"]))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
# imputing the null values with mean ,median,mode values .

df["Overall Rating"].fillna(df["Overall Rating"].mean(),inplace=True)
df['Trip_verified'].fillna(df["Trip_verified"].mode()[0],inplace=True)
df["Aircraft"].fillna(df["Aircraft"].mode()[0],inplace=True)
df["Type Of Traveller"].fillna(df["Type Of Traveller"].mode()[0],inplace=True)
df["Origin"].fillna(df["Origin"].mode()[0],inplace=True)
df["Seat Comfort"].fillna(df["Seat Comfort"].mean(),inplace=True)
df['Cabin Staff Service'].fillna(df["Cabin Staff Service"].mean(),inplace=True)
df["Food & Beverages"].fillna(df["Food & Beverages"].mean(),inplace=True)
df["Ground Service"].fillna(df["Ground Service"].median(),inplace=True)
df["Value For Money"].fillna(df["Value For Money"].mean(),inplace=True)
df["Inflight Entertainment"].fillna(df["Inflight Entertainment"].median(),inplace=True)
df["Wifi & Connectivity"].fillna(df["Wifi & Connectivity"].median(),inplace=True)

# %%
# again checking for null values.
df.isnull().sum()
# Out:
# Date Published              0
# Overall Rating              0
# Passenger Country           0
# Trip_verified               0
# Comment title               0
# Comment                     0
# Aircraft                    0
# Type Of Traveller           0
# Seat Type                   0
# Origin                      0
# Destination               615
# Date Flown                618
# Seat Comfort                0
# Cabin Staff Service         0
# Food & Beverages            0
# Ground Service              0
# Value For Money             0
# Recommended                 0
# Inflight Entertainment      0
# Wifi & Connectivity         0
# dtype: int64

# %%
df["Destination"].fillna(df["Destination"].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Date Published              0
# Overall Rating              0
# Passenger Country           0
# Trip_verified               0
# Comment title               0
# Comment                     0
# Aircraft                    0
# Type Of Traveller           0
# Seat Type                   0
# Origin                      0
# Destination                 0
# Date Flown                618
# Seat Comfort                0
# Cabin Staff Service         0
# Food & Beverages            0
# Ground Service              0
# Value For Money             0
# Recommended                 0
# Inflight Entertainment      0
# Wifi & Connectivity         0
# dtype: int64

# %%
no_null_data=df.dropna()

# %%
no_null_data
# Out:
#      Date Published  Overall Rating Passenger Country  Trip_verified  \
# 0        2024-02-03            10.0    United Kingdom   Not Verified
# 1        2024-01-26            10.0    United Kingdom  Trip Verified
# 2        2024-01-20            10.0    United Kingdom  Trip Verified
# 3        2024-01-07             6.0    United Kingdom  Trip Verified
# 4        2024-01-06            10.0            Israel  Trip Verified
# ...             ...             ...               ...            ...
# 1626     2015-06-18             5.0            Greece  Trip Verified
# 1627     2015-06-14            10.0             Spain  Trip Verified
# 1629     2015-06-13             2.0    United Kingdom  Trip Verified
# 1630     2015-06-13             1.0    United Kingdom  Trip Verified
# 1631     2015-06-13             2.0            Poland  Trip Verified
#
#                                  Comment title  \
# 0            "bang on time and smooth flights"
# ...

# %%
# converting the Date_published column into date datatype.
no_null_data["Date Published"]=pd.to_datetime(no_null_data["Date Published"])

# %%
no_null_data
# Out:
#      Date Published  Overall Rating Passenger Country  Trip_verified  \
# 0        2024-02-03            10.0    United Kingdom   Not Verified
# 1        2024-01-26            10.0    United Kingdom  Trip Verified
# 2        2024-01-20            10.0    United Kingdom  Trip Verified
# 3        2024-01-07             6.0    United Kingdom  Trip Verified
# 4        2024-01-06            10.0            Israel  Trip Verified
# ...             ...             ...               ...            ...
# 1626     2015-06-18             5.0            Greece  Trip Verified
# 1627     2015-06-14            10.0             Spain  Trip Verified
# 1629     2015-06-13             2.0    United Kingdom  Trip Verified
# 1630     2015-06-13             1.0    United Kingdom  Trip Verified
# 1631     2015-06-13             2.0            Poland  Trip Verified
#
#                                  Comment title  \
# 0            "bang on time and smooth flights"
# ...

# %%
no_null_data['year']=pd.to_datetime(no_null_data['Date Published']).dt.year

# %%
no_null_data.drop_duplicates(inplace=True)

# %%
no_null_data
# Out:
#      Date Published  Overall Rating Passenger Country  Trip_verified  \
# 0        2024-02-03            10.0    United Kingdom   Not Verified
# 1        2024-01-26            10.0    United Kingdom  Trip Verified
# 2        2024-01-20            10.0    United Kingdom  Trip Verified
# 3        2024-01-07             6.0    United Kingdom  Trip Verified
# 4        2024-01-06            10.0            Israel  Trip Verified
# ...             ...             ...               ...            ...
# 1626     2015-06-18             5.0            Greece  Trip Verified
# 1627     2015-06-14            10.0             Spain  Trip Verified
# 1629     2015-06-13             2.0    United Kingdom  Trip Verified
# 1630     2015-06-13             1.0    United Kingdom  Trip Verified
# 1631     2015-06-13             2.0            Poland  Trip Verified
#
#                                  Comment title  \
# 0            "bang on time and smooth flights"
# ...

# %% [markdown]
# # Checking for particular columns

# %% [markdown]
# ## for Date Published column

# %%
no_null_data["Date Published"].unique()
# Out:
# <DatetimeArray>
# ['2024-02-03 00:00:00', '2024-01-26 00:00:00', '2024-01-20 00:00:00',
#  '2024-01-07 00:00:00', '2024-01-06 00:00:00', '2024-01-03 00:00:00',
#  '2023-12-25 00:00:00', '2023-12-08 00:00:00', '2023-12-06 00:00:00',
#  '2023-12-04 00:00:00',
#  ...
#  '2015-07-10 00:00:00', '2015-07-06 00:00:00', '2015-07-04 00:00:00',
#  '2015-07-03 00:00:00', '2015-06-29 00:00:00', '2015-06-28 00:00:00',
#  '2015-06-27 00:00:00', '2015-06-18 00:00:00', '2015-06-14 00:00:00',
#  '2015-06-13 00:00:00']
# Length: 1150, dtype: datetime64[ns]

# %%
# value counts
no_null_data["Date Published"].value_counts().head(5)
# Out:
# Date Published
# 2019-10-17    6
# 2016-11-20    5
# 2015-09-19    5
# 2019-09-02    5
# 2015-10-07    5
# Name: count, dtype: int64

# %%
# checking for the airline year-wise have maximum flight
no_null_data.groupby(['year','Date Published'])["Date Flown"].count()
# Out:
# year  Date Published
# 2015  2015-06-13        3
#       2015-06-14        1
#       2015-06-18        1
#       2015-06-27        1
#       2015-06-28        2
#                        ..
# 2024  2024-01-06        2
#       2024-01-07        1
#       2024-01-20        1
#       2024-01-26        1
#       2024-02-03        1
# Name: Date Flown, Length: 1150, dtype: int64

# %%
# checking for latest year total flights 
no_null_data[no_null_data['year']==2024]
# Out:
#   Date Published  Overall Rating Passenger Country  Trip_verified  \
# 0     2024-02-03            10.0    United Kingdom   Not Verified
# 1     2024-01-26            10.0    United Kingdom  Trip Verified
# 2     2024-01-20            10.0    United Kingdom  Trip Verified
# 3     2024-01-07             6.0    United Kingdom  Trip Verified
# 4     2024-01-06            10.0            Israel  Trip Verified
# 5     2024-01-06             1.0           Denmark   Not Verified
# 6     2024-01-03             5.0    United Kingdom   Not Verified
# 7     2024-01-03             1.0         Australia  Trip Verified
#
#                               Comment title  \
# 0         "bang on time and smooth flights"
# 1          "Another good affordable flight"
# 2                       “Really impressed!”
# 3          “a decent offering from Ryanair”
# 4  “cabin crew were welcoming and friendly”
# 5     "close online checkin 3 hours before"
# 6        "they are really not better value"
# ...

# %% [markdown]
# Report:
#     In year 2024, we have departured 8 flights .

# %%
# checking for solo traveller trvel in 2024.
no_null_data[(no_null_data['year']==2024) & (no_null_data["Type Of Traveller"]=="Solo Leisure")]
# Out:
#   Date Published  Overall Rating Passenger Country  Trip_verified  \
# 3     2024-01-07             6.0    United Kingdom  Trip Verified
# 4     2024-01-06            10.0            Israel  Trip Verified
# 5     2024-01-06             1.0           Denmark   Not Verified
# 7     2024-01-03             1.0         Australia  Trip Verified
#
#                               Comment title  \
# 3          “a decent offering from Ryanair”
# 4  “cabin crew were welcoming and friendly”
# 5     "close online checkin 3 hours before"
# 7        "asked me to pay for the backpack"
#
#                                              Comment        Aircraft  \
# 3  I should like to review my flight from Faro to...      Boeing 737
# 4  Flight left the gate ahead of schedule, fare w...  Boeing 737-800
# 5  Booked a fight from Copenhagen to Poland thoug...  Boeing 737-800
# 7  Staff is rude and has no manners, let alone be...  Boeing 737-800
#
# ...

# %% [markdown]
# Report:
#
#     There are 4 passengers travel solo in year 2024.

# %%
sb.histplot(no_null_data["year"])
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %% [markdown]
# REPORT :
#
#     (1).In year 2019, the maximum numbers of passengers travel through airlines with count value of 350.
#
#     (2).In year 2018, Nearly 280-290 numbers of passengers travel through airlines.
#
#     (3).In year 2015, Nearly 210-220 numbers of passengers travel through airlines.
#
#     (4).In year 2016 and 2017 , There are same numbers of passengers travel through airlines which is about 165-180.
#
#     (5).In year 2020 passengers counts below 150 and in year 2021 passengers count below 100.
#
#     (6).In current year 2024, There are almost 8-10 passengers travel through airlines.

# %% [markdown]
# # (2).Overall Rating column

# %%
# checking for unique 
no_null_data["Overall Rating"].unique()
# Out:
# array([10.,  6.,  1.,  5.,  8.,  3.,  9.,  2.,  7.,  4.])

# %%
no_null_data['Overall Rating'].nunique()
# Out:
# 10

# %% [markdown]
# # Report :
#
#     There are total 10 unique values in overall rating columnn.

# %%
# counting the values based on there rating.
no_null_data["Overall Rating"].value_counts()
# Out:
# Overall Rating
# 1.0     804
# 2.0     141
# 10.0    130
# 9.0     122
# 8.0     116
# 7.0      87
# 3.0      81
# 6.0      57
# 5.0      53
# 4.0      40
# Name: count, dtype: int64

# %% [markdown]
# # Report :
#
#     There are 130 numbers of count for rating 10.0.
#
#     There are 122 numbers of count for rating 9.0.
#
#     There are 116 numbers of count for rating 8.0.
#
#     There are maximum numbers of count for rating 1.0
#
#     There are minimum numbers of count for rating 4.0 which is about 40.

# %%
# plotting the graph

sb.histplot(no_null_data["Overall Rating"])
# Out:
# <Axes: xlabel='Overall Rating', ylabel='Count'>

# %%
# checking for data which are having rating with 10 and trip verified.
no_null_data[(no_null_data["Overall Rating"]==10.0) &(no_null_data["Trip_verified"]=="Trip Verified")]
# Out:
#      Date Published  Overall Rating Passenger Country  Trip_verified  \
# 1        2024-01-26            10.0    United Kingdom  Trip Verified
# 2        2024-01-20            10.0    United Kingdom  Trip Verified
# 4        2024-01-06            10.0            Israel  Trip Verified
# 20       2023-10-23            10.0           Belarus  Trip Verified
# 60       2023-07-06            10.0         Australia  Trip Verified
# ...             ...             ...               ...            ...
# 1611     2015-07-11            10.0            Canada  Trip Verified
# 1617     2015-07-04            10.0    United Kingdom  Trip Verified
# 1623     2015-06-28            10.0    United Kingdom  Trip Verified
# 1624     2015-06-28            10.0    United Kingdom  Trip Verified
# 1627     2015-06-14            10.0             Spain  Trip Verified
#
#                                  Comment title  \
# 1             "Another good affordable flight"
# ...

# %%
sb.catplot(x="Type Of Traveller",y="Overall Rating",hue="Trip_verified",data=no_null_data, kind="bar")

# %% [markdown]
# # Passenger Country columns

# %%
no_null_data["Passenger Country"].values
# Out:
# array(['United Kingdom', 'United Kingdom', 'United Kingdom', ...,
#        'United Kingdom', 'United Kingdom', 'Poland'], dtype=object)

# %%
# checking unique values
no_null_data['Passenger Country'].unique()
# Out:
# array(['United Kingdom', 'Israel', 'Denmark', 'Australia', 'Germany',
#        'Albania', 'Singapore', 'Portugal', 'Canada', 'Spain', 'Belarus',
#        'Norway', 'United States', 'Sweden', 'Belgium', 'Iraq',
#        'United Arab Emirates', 'Czech Republic', 'Greece', 'Morocco',
#        'Ireland', 'Netherlands', 'Gibraltar', 'India', 'Slovenia',
#        'South Africa', 'Switzerland', 'New Zealand', 'Austria', 'France',
#        'Italy', 'Slovakia', 'Croatia', 'Hungary', 'Lithuania', 'Poland',
#        'Finland', 'Latvia', 'Ukraine', 'Luxembourg', 'Indonesia',
#        'Romania', 'Malta', 'Estonia', 'Cyprus', 'Macedonia', 'Bulgaria',
#        'Mexico', 'Vietnam', 'Lebanon', 'Serbia', 'Turkey', 'Malaysia',
#        'Jordan', 'Philippines', 'Japan', 'Egypt', 'Russian Federation',
#        'Chile', 'Hong Kong', 'Iceland', 'Thailand', 'Kuwait', 'Brazil',
#        'Laos', 'Qatar', 'China', 'Argentina', 'Pakistan', 'Brunei'],
#       dtype=object)

# %%
# checking for numbers of passengers based on there country.
no_null_data["Passenger Country"].value_counts()
# Out:
# Passenger Country
# United Kingdom    710
# United States     144
# Ireland           114
# Germany            69
# Canada             50
#                  ...
# Malaysia            1
# Serbia              1
# Vietnam             1
# Macedonia           1
# Brunei              1
# Name: count, Length: 70, dtype: int64

# %%
# top 5
no_null_data["Passenger Country"].value_counts().head(5)
# Out:
# Passenger Country
# United Kingdom    710
# United States     144
# Ireland           114
# Germany            69
# Canada             50
# Name: count, dtype: int64

# %% [markdown]
# Report:
#
#     TOP FIVE COUNTRIES WITH MAXIMUM PASSENGERS COUNT.
#
#     There are total 710 passengers from country UK.
#
#     There are total 144 passengers from US.
#
#     There are 114 passengers from Ireland.
#
#     There are 69 passengers from Germany.
#
#     There are 50 passengers from Canada.

# %%
# Checking for data with country "United kingdom"

no_null_data[no_null_data["Passenger Country"]=='United Kingdom']
# Out:
#      Date Published  Overall Rating Passenger Country  Trip_verified  \
# 0        2024-02-03            10.0    United Kingdom   Not Verified
# 1        2024-01-26            10.0    United Kingdom  Trip Verified
# 2        2024-01-20            10.0    United Kingdom  Trip Verified
# 3        2024-01-07             6.0    United Kingdom  Trip Verified
# 6        2024-01-03             5.0    United Kingdom   Not Verified
# ...             ...             ...               ...            ...
# 1623     2015-06-28            10.0    United Kingdom  Trip Verified
# 1624     2015-06-28            10.0    United Kingdom  Trip Verified
# 1625     2015-06-27             2.0    United Kingdom  Trip Verified
# 1629     2015-06-13             2.0    United Kingdom  Trip Verified
# 1630     2015-06-13             1.0    United Kingdom  Trip Verified
#
#                            Comment title  \
# 0      "bang on time and smooth flights"
# 1       "Another good affordable flight"
# ...

# %%
# Checking for overall rating 10 from first class.
no_null_data[(no_null_data["Passenger Country"]=="United Kingdom") & (no_null_data["Overall Rating"]==10) & (no_null_data['Seat Type']=='First Class')]
# Out:
#      Date Published  Overall Rating Passenger Country  Trip_verified  \
# 1451     2015-11-19            10.0    United Kingdom  Trip Verified
#
#                     Comment title  \
# 1451  "paid only £70 each return"
#
#                                                 Comment        Aircraft  \
# 1451  We have flown Ryanair numerous times over the ...  Boeing 737-800
#
#      Type Of Traveller    Seat Type    Origin  ...     Date Flown  \
# 1451    Couple Leisure  First Class  Stansted  ...  November 2015
#
#      Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# 1451          5.0                  5.0          1.921494             4.0
#
#       Value For Money  Recommended Inflight Entertainment  \
# 1451              5.0          yes                    1.0
#
#       Wifi & Connectivity  year
# 1451                  1.0  2015
#
# [1 rows x 21 columns]

# %%
# Checking for overall rating 10 from Economy class.
no_null_data[(no_null_data["Passenger Country"]=="United Kingdom") & (no_null_data["Overall Rating"]==10) & (no_null_data['Seat Type']=='Economy Class')]
# Out:
#      Date Published  Overall Rating Passenger Country  Trip_verified  \
# 0        2024-02-03            10.0    United Kingdom   Not Verified
# 1        2024-01-26            10.0    United Kingdom  Trip Verified
# 2        2024-01-20            10.0    United Kingdom  Trip Verified
# 95       2023-05-02            10.0    United Kingdom  Trip Verified
# 96       2023-05-02            10.0    United Kingdom  Trip Verified
# ...             ...             ...               ...            ...
# 1571     2015-08-23            10.0    United Kingdom  Trip Verified
# 1586     2015-08-10            10.0    United Kingdom  Trip Verified
# 1617     2015-07-04            10.0    United Kingdom  Trip Verified
# 1623     2015-06-28            10.0    United Kingdom  Trip Verified
# 1624     2015-06-28            10.0    United Kingdom  Trip Verified
#
#                           Comment title  \
# 0     "bang on time and smooth flights"
# 1      "Another good affordable flight"
# ...

# %%
pd.DataFrame(no_null_data.groupby("Passenger Country")["Passenger Country"].value_counts().sort_values(ascending=False).head(5))
# Out:
#                    count
# Passenger Country
# United Kingdom       710
# United States        144
# Ireland              114
# Germany               69
# Canada                50

# %% [markdown]
# # Aircraft column

# %%
no_null_data["Aircraft"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1631 entries, 0 to 1631
# Series name: Aircraft
# Non-Null Count  Dtype
# --------------  -----
# 1631 non-null   object
# dtypes: object(1)
# memory usage: 25.5+ KB

# %%
# checking the unique values from it.
no_null_data["Aircraft"].unique()
# Out:
# array(['Boeing 737 900', 'Boeing 737-800', 'Boeing 737', 'Boeing 737Max',
#        'Boeing 737 800', 'Boeing 737-8200', 'B733-8022', 'Boeing 347',
#        'Boeing 737 max', 'Boeing 737-10', 'B737', 'Boeing 737 Max 8',
#        '737 800', 'Boeing 737 Max', 'Boeing 737 MAX', 'Boeing 737-8AS',
#        'A320', 'Boeing 737 MAX 8-200', 'Boeing 738', 'Boeing 737max',
#        'Boeing 737-800 NG', 'Boeing 747-400', 'Boeing 373-800',
#        'Bowen 737', 'Boeing 747', 'FR8852', 'Boeing 737-400',
#        'Boeing  737-800', 'B737 800', 'Boeing 737-8', 'A340',
#        'Boeing 737-700', 'A319', 'B737-800', 'Boeing 737- 800',
#        'Boeing 737 - 800', 'Boing 737-800', 'Boeing', 'Boeing 747-800',
#        'Boeing 737-900', 'Boeing 737-800 EI-ENX', 'Boeing 737 / 800',
#        'B747', 'Boeing 737-800 series', '737300', 'Boeing 737-300',
#        'A-340', 'Boeing 737/800', 'Boeing 737-800WL'], dtype=object)

# %%
no_null_data["Aircraft"].nunique()
# Out:
# 49

# %% [markdown]
# # REPORT :
#
#     There are total 49 Aircraft in a airline.

# %%
no_null_data["Aircraft"].count()
# Out:
# 1631

# %%
no_null_data["Aircraft"].value_counts()
# Out:
# Aircraft
# Boeing 737-800           1402
# Boeing 737                139
# Boeing 737 800              9
# Boeing 738                  8
# Boeing 737-8AS              6
# B737-800                    6
# A320                        5
# Boeing 747                  5
# B737                        4
# Boeing 737 Max              3
# A340                        2
# Boeing 737-8                2
# 737 800                     2
# Boeing 737 MAX              2
# Boeing 747-400              2
# Boeing                      1
# A319                        1
# Boeing 737/800              1
# Boeing 737- 800             1
# Boeing 737 - 800            1
# A-340                       1
# Boing 737-800               1
# Boeing 737-800 series       1
# Boeing 747-800              1
# B747                        1
# Boeing 737-300              1
# Boeing 737-800 EI-ENX       1
# 737300                      1
# Boeing 737-700              1
# Boeing 737 / 800            1
# ...

# %% [markdown]
# Report:
#
#     (1). Aircraft Boeing 737-800   have the maximum  travel count of 1402.
#
#     (2). Aircraft Boeing 737 have the second maximum  travel count of 139.

# %%
# checking for Boeing 737-800 travel data in current year.

data1=no_null_data[(no_null_data["Aircraft"]=='Boeing 737-800') & (no_null_data['year']==2024)]

# %%
data1
# Out:
#   Date Published  Overall Rating Passenger Country  Trip_verified  \
# 1     2024-01-26            10.0    United Kingdom  Trip Verified
# 2     2024-01-20            10.0    United Kingdom  Trip Verified
# 4     2024-01-06            10.0            Israel  Trip Verified
# 5     2024-01-06             1.0           Denmark   Not Verified
# 7     2024-01-03             1.0         Australia  Trip Verified
#
#                               Comment title  \
# 1          "Another good affordable flight"
# 2                       “Really impressed!”
# 4  “cabin crew were welcoming and friendly”
# 5     "close online checkin 3 hours before"
# 7        "asked me to pay for the backpack"
#
#                                              Comment        Aircraft  \
# 1  Another good affordable flight with Ryanair. O...  Boeing 737-800
# 2  Really impressed! You get what you pay for, th...  Boeing 737-800
# 4  Flight left the gate ahead of schedule, fare w...  Boeing 737-800
# ...

# %% [markdown]
# Report :
#
#     (1) There are only 5 travel done by Boeing 737-800 in year 2024.
#
#     (2) We have passenger overall rating with maximum rating of 10.

# %%
# counting the passenger travelling in airlines.
sb.histplot(data1["Overall Rating"])
# Out:
# <Axes: xlabel='Overall Rating', ylabel='Count'>

# %%
# plotting histplot for Trip_verified.
sb.histplot(no_null_data["Trip_verified"])
# Out:
# <Axes: xlabel='Trip_verified', ylabel='Count'>

# %%
sb.pairplot(data=no_null_data)

# %%
no_null_data.dtypes
# Out:
# Date Published            datetime64[ns]
# Overall Rating                   float64
# Passenger Country                 object
# Trip_verified                     object
# Comment title                     object
# Comment                           object
# Aircraft                          object
# Type Of Traveller                 object
# Seat Type                         object
# Origin                            object
# Destination                       object
# Date Flown                        object
# Seat Comfort                     float64
# Cabin Staff Service              float64
# Food & Beverages                 float64
# Ground Service                   float64
# Value For Money                  float64
# Recommended                       object
# Inflight Entertainment           float64
# Wifi & Connectivity              float64
# year                               int32
# dtype: object

# %% [markdown]
# ### columns which are containg numeric data in it.

# %%
numeric_data=no_null_data.select_dtypes(include=[np.number])

# %%
numeric_data
# Out:
#       Overall Rating  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0               10.0           4.0                  5.0          3.000000
# 1               10.0           3.0                  5.0          3.000000
# 2               10.0           5.0                  5.0          4.000000
# 3                6.0           3.0                  2.0          1.000000
# 4               10.0           4.0                  5.0          1.921494
# ...              ...           ...                  ...               ...
# 1626             5.0           3.0                  4.0          1.921494
# 1627            10.0           2.0                  5.0          5.000000
# 1629             2.0           2.0                  1.0          1.921494
# 1630             1.0           3.0                  2.0          1.000000
# 1631             2.0           3.0                  1.0          1.921494
#
#       Ground Service  Value For Money  Inflight Entertainment  \
# ...

# %%
# plotting the scatter graph


sb.scatterplot(x="Seat Comfort",y="Overall Rating",data=no_null_data)
# Out:
# <Axes: xlabel='Seat Comfort', ylabel='Overall Rating'>

# %%
# checking the relation with overall rating and value for money

sb.relplot(x="Value For Money",y="Overall Rating",data=no_null_data)

# %%
sb.regplot(x="Value For Money",y="Overall Rating",data=no_null_data)
# Out:
# <Axes: xlabel='Value For Money', ylabel='Overall Rating'>

# %%
sb.relplot(x="Value For Money",y="Overall Rating",hue="Type Of Traveller",data=no_null_data)

# %%
# checking for the relation with overall rating and seat comfort ,recommended

sb.relplot(x="Value For Money",y="Overall Rating",hue="Recommended",data=no_null_data)

# %%
# plottng histogram graph for counting the passengers recommendation.

sb.histplot(no_null_data["Recommended"])
# Out:
# <Axes: xlabel='Recommended', ylabel='Count'>

# %% [markdown]
# ## Outlier removing and detecting:

# %%
# plotting box plot for checking the outliers.

sb.boxplot(x=numeric_data['Cabin Staff Service'])
# Out:
# <Axes: xlabel='Cabin Staff Service'>

# %%
sb.boxplot(x=numeric_data['Value For Money'])
# Out:
# <Axes: xlabel='Value For Money'>

# %%
sb.boxplot(x=numeric_data['Food & Beverages'])
# Out:
# <Axes: xlabel='Food & Beverages'>

# %%
sb.histplot(numeric_data["Food & Beverages"],kde=True)
# Out:
# <Axes: xlabel='Food & Beverages', ylabel='Count'>

# %%
sb.boxplot(x=numeric_data['Ground Service'])
# Out:
# <Axes: xlabel='Ground Service'>

# %%
sb.boxplot(x=numeric_data['Inflight Entertainment'])
# Out:
# <Axes: xlabel='Inflight Entertainment'>

# %%
sb.histplot(numeric_data["Inflight Entertainment"],kde=True)
# Out:
# <Axes: xlabel='Inflight Entertainment', ylabel='Count'>

# %%
sb.boxplot(x=numeric_data['Overall Rating'])
# Out:
# <Axes: xlabel='Overall Rating'>

# %%
sb.boxplot(x=numeric_data['Seat Comfort'])
# Out:
# <Axes: xlabel='Seat Comfort'>

# %%
sb.boxplot(x=numeric_data['Wifi & Connectivity'])
# Out:
# <Axes: xlabel='Wifi & Connectivity'>

# %%
# checking fot the summary of data
numeric_data.describe().transpose()
# Out:
#                          count         mean       std     min          25%  \
# Overall Rating          1631.0     3.697731  3.358168     1.0     1.000000
# Seat Comfort            1631.0     2.179536  1.196633     1.0     1.000000
# Cabin Staff Service     1631.0     2.633604  1.459006     1.0     1.000000
# Food & Beverages        1631.0     1.993622  0.869629     1.0     1.921494
# Ground Service          1631.0     2.118945  1.480947     1.0     1.000000
# Value For Money         1631.0     2.518536  1.664312     1.0     1.000000
# Inflight Entertainment  1631.0     1.029430  0.243426     1.0     1.000000
# Wifi & Connectivity     1631.0     1.020233  0.221999     1.0     1.000000
# year                    1631.0  2018.493562  2.384212  2015.0  2017.000000
#
#                                 50%          75%     max
# Overall Rating             2.000000     7.000000    10.0
# Seat Comfort               2.000000     3.000000     5.0
# ...

# %%
# checking for wifi & Connectivity rating greater than 1.
no_null_data[no_null_data['Wifi & Connectivity']>1]
# Out:
#      Date Published  Overall Rating Passenger Country    Trip_verified  \
# 5        2024-01-06             1.0           Denmark     Not Verified
# 225      2022-06-13             1.0    United Kingdom     Not Verified
# 229      2022-06-08             7.0    United Kingdom     Not Verified
# 355      2020-07-08             2.0    United Kingdom     Not Verified
# 445      2019-12-11             6.0    United Kingdom     Not Verified
# 486      2019-11-02             5.0           Ireland    Trip Verified
# 492      2019-10-25             8.0             Spain     Not Verified
# 528      2019-09-30            10.0    United Kingdom     Not Verified
# 577      2019-08-30            10.0    United Kingdom    Trip Verified
# 699      2019-04-30             1.0           Germany    Trip Verified
# 705      2019-04-25             2.0     United States    Trip Verified
# 780      2019-01-13             2.0     United States    Trip Verified
# ...

# %%
#AS THERE IS NO OUTLIER IN OUR DATASET WE ARE SAVING IT INTO CSV
no_null_data.to_csv("Airline_dataset.csv",index=False)
