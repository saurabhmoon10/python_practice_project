# %%
#importing the necessary libs
import pandas as pd 
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as plx
import warnings

warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## dataset loading

# %%
netflix_data=pd.read_csv(r"C:\Users\HP\Downloads\netflix.csv")

# %%
netflix_data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# copying the dataset in new variable for analysis
data=netflix_data.copy()

# %% [markdown]
# ## EDA starts from here

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# checking the sample of the data
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# checking the  number of columns in a dataset
data.columns.nunique()
# Out:
# 11

# %%
# checking the label name of columns in a dataset
data.columns.unique()
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
#checking for the information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
# checking for the number of null values
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ### Report :
# (1) Director column has maximum non values filled in it with numbers of 2388.
#
# (2) Cast column has second maximum non values filled in it after Director column with numbers of 718.
#
# (3) Country columns has a non values filled in it with numbers of 507.
#
# (4) Release_Date  has a non values filled in it with numbers of 10.
#
# (5) Rating has a non values filled in it with numbers of 7.

# %%
data[data.duplicated()].count()
# Out:
# Show_Id         2
# Category        2
# Title           2
# Director        2
# Cast            2
# Country         2
# Release_Date    2
# Rating          2
# Duration        2
# Type            2
# Description     2
# dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# ### Report:
# There are 10 duplicated values in a dataset.
#
# Dropped the duplicated values from a dataset.

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ### Report :
# After dropping the duplicate values from a dataset We have 7787 rows and 11 columns.

# %%
sb.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Report :
#  Heatmap shows the null values from a given data.

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ### Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
data[data["Title"].isin(["House of Cards"])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data[data["Title"]=="House of Cards"]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
# converting the date into year
data["year"]=pd.to_datetime(data["Release_Date"],errors="coerce",).dt.year

# %%
data.dtypes
# Out:
# Show_Id          object
# Category         object
# Title            object
# Director         object
# Cast             object
# Country          object
# Release_Date     object
# Rating           object
# Duration         object
# Type             object
# Description      object
# year            float64
# dtype: object

# %%
data["year"].unique()
# Out:
# array([2020., 2016., 2018., 2017., 2019., 2021., 2015., 2013., 2011.,
#          nan, 2012., 2014., 2008., 2009., 2010.])

# %%
data["year"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description    year
# 0  In a future where the elite inhabit an island ...  2020.0
# 1  After a devastating earthquake hits Mexico Cit...  2016.0

# %%
data.groupby("Category")["Title"].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
sb.countplot(x="Category",data=data)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# ### Q. 4) Show all the Movies that were released in year 2000.

# %%
data[(data["Category"]=="Movie") & (data["year"]==2000.0)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year]
# Index: []

# %% [markdown]
# So there is no movie released in year 2000

# %% [markdown]
# ### Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
data[(data["Category"]=="TV Show") & (data["Country"]=="India")]["Title"]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
data["Director"].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
# ### Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
data[(data["Category"]=="Movie") & (data["Type"]=="Comedies")| (data["Country"]=="United Kingdom")]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ### Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
# dropping the null values 
new_data=data.dropna()

# %%
# new dataset is created with filter null values

new_data
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
# now checking for the cast "Tom Cruise"
# this won't work becaz there is a group of names 
new_data[new_data["Cast"]=="Tom Cruise"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year]
# Index: []

# %%
# using str.contains
new_data[new_data["Cast"].str.contains("Tom Cruise")]["Title"].count()
# Out:
# 2

# %%
 # Name of the movies in which Tom Cruise is featured.
    new_data[new_data["Cast"].str.contains("Tom Cruise")]["Title"]
# Out:
# 3860    Magnolia
# 5071    Rain Man
# Name: Title, dtype: object

# %% [markdown]
# ### Q. 9) What are the different Ratings defined by Netflix ?

# %%
new_data["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#getting the numbers of it
new_data["Rating"].nunique()
# Out:
# 14

# %% [markdown]
# ### Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
new_data[(new_data["Rating"]=="TV-14") & (new_data["Country"]=="Canada")&(new_data["Category"]=="Movie")]["Title"].count()
# Out:
# 9

# %% [markdown]
# ### Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
new_data[(new_data["Category"]=="TV Show") & (new_data["Rating"]=="R")]

# as it shows no output becaz in new data we have removed all the nan values .

# %%
data[(data["Category"]=="TV Show") & (data["Rating"]=="R") & (data["year"]>2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description    year
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019.0

# %% [markdown]
# ### Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
data.groupby("Category")["Duration"].max()
# Out:
# Category
# Movie         99 min
# TV Show    9 Seasons
# Name: Duration, dtype: object

# %%
# different way
data["Duration"].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data["Duration"].dtype
# Out:
# dtype('O')

# %%
# spliting the minutes and unit 
data[["minute","unit"]]=data["Duration"].str.split(' ',expand=True)

# %%
# checking the sample
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description    year minute     unit
# 0  In a future where the elite inhabit an island ...  2020.0      4  Seasons
# 1  After a devastating earthquake hits Mexico Cit...  2016.0     93      min

# %%
# checking for the maximum value
data["minute"].max()
# Out:
# '99'

# %% [markdown]
# ### Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
#Sample of data
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description    year minute     unit
# ...

# %%
# Getting a data which have TV shows
TV_show=data[data["Category"]=="TV Show"]

# %%
TV_show.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description    year minute     unit
# 0  In a future where the elite inhabit an island ...  2020.0      4  Seasons
# 5  A genetics professor experiments with a treatm...  2017.0      1   Season

# %%
# Individual country has highest No. of Tv-show 
TV_show.Country.value_counts().head(5)
# Out:
# Country
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Name: count, dtype: int64

# %% [markdown]
# ### Q. 12) How can we sort the dataset by Year ?

# %%
# ascending order
data.sort_values("year")
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five                   NaN
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                          ...                   ...
# 6952   s6951  TV Show                   The Tudors                   NaN
# 6998   s6997  TV Show                The West Wing                   NaN
# 7448   s7447  TV Show                      Vroomiz                   NaN
# 7524   s7523  TV Show   Weird Wonders of the World                   NaN
# 7655   s7654  TV Show            Women Behind Bars                   NaN
#
#                                                    Cast  \
# ...

# %%
# sorting the dataset in descending order
data.sort_values(by='year',ascending=False)
# Out:
#      Show_Id Category                                              Title  \
# 5564   s5564    Movie                                    Sherlock Holmes
# 5919   s5919    Movie                                          Surf's Up
# 980     s981  TV Show                                       Bling Empire
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5955   s5955    Movie                                   Taare Zameen Par
# ...      ...      ...                                                ...
# 6952   s6951  TV Show                                         The Tudors
# 6998   s6997  TV Show                                      The West Wing
# 7448   s7447  TV Show                                            Vroomiz
# 7524   s7523  TV Show                         Weird Wonders of the World
# 7655   s7654  TV Show                                  Women Behind Bars
#
#                      Director  \
# 5564              Guy Ritchie
# ...

# %% [markdown]
# ### Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
data[(data["Category"]=="Movie") & (data["Type"]=="Dramas") | (data["Category"]=="TV Show") & (data["Type"]=="Kids TV")]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
